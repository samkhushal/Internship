# %% [markdown]
# <a href="https://colab.research.google.com/github/samkhushal/Internship/blob/main/Task2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Task 2
#
# **Simple Data Visualization**
#
# Create a basic bar chart or line chart using a popular Python visualization library like Matplotlib or Seaborn. Visualize key insights from the dataset.

# %% [markdown]
# Data set Link:-
#  https://www.kaggle.com/datasets/shwetabh123/mall-customers

# %%
from google.colab import files
up = files.upload()
# Out:
#      <input type="file" id="files-1222d8f2-6cf1-4f85-874f-97c5a28aed74" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1222d8f2-6cf1-4f85-874f-97c5a28aed74">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
pip install matplotlib

# %%
import matplotlib.pyplot as plt
import pandas as pd
import io

# %%
data = pd.read_csv(io.BytesIO(up["Mall_Customers.csv"]))

# %%
df = data

# %%
df.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %%
print(df)
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
df.shape
# Out:
# (200, 5)

# %%
df.head()
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
df.tail()
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83

# %%
from matplotlib import pyplot as plt
_df_61['CustomerID'].plot(kind='hist', bins=20, title='Customer Id')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_43['Spending Score (1-100)'].plot(kind='hist', bins=20, title='Spending Score (1-100)')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_24.groupby('Genre').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# From Graph No 2 we get to know that male customers are more than female customer

# %%
import matplotlib.pyplot as plt
Age = df['Age']
AnnualIncome = df['Annual Income (k$)']
plt.bar(Age,AnnualIncome )
plt.show()

# %%
Age.max()
# Out:
# 70

# %% [markdown]
# Above graph shows that maximum annual income ranges from 30-35 & 45-50

# %%
import matplotlib.pyplot as plt


df = pd.DataFrame({
    'age': [10, 20, 30, 40, 50],
    'customer_id': [1, 2, 3, 4, 5]
})


plt.bar(df['age'], df['customer_id'])

plt.show()
